# %% [markdown]
# ## Ukraine EuRepoC Research
#
# In this notebook, we will construct a links list from sources of incidents in EuRepoC database impact Ukraine. The EuRepoC database has information about the receiver country; however, it does not have information about specific cities or provinces impacted. We will extract this new information for incidents that impact Ukraine.
#
# We will leverage `UkraineCyberMultiScraper`, a custom `MultiScraper` that combines several specific scrapers including `CertUaScraper`, as well as [`TelegramMessageScraper`, a fallback `NewsScraper`, and a `TextScraper`](https://scraipe.readthedocs.io/en/latest/get_started/bundled_components/).

# %% [markdown]
# ## Setup
# Install packages, load dataset, and load credentials from secrets.env.

# %%
# %pip install scraipe-cyber --quiet
# %pip install dotenv --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# A template `secrets.env.template` file is provided that should be renamed to `secrets.env` and filled in with your credentials.

# %%
# Import Dependencies
from scraipe_cyber.ukraine import UkraineCyberMultiScraper
from scraipe.extended import TelegramMessageScraper
from scraipe.extended import OpenAiAnalyzer
from scraipe import Workflow
import pandas as pd
import re
import dotenv
import os

# %%
# Load credentials for telegram and openai
dotenv.load_dotenv('secrets.env')
telegram_api_id = os.getenv('TELEGRAM_API_ID')
telegram_api_hash = os.getenv('TELEGRAM_API_HASH')
openai_key = os.getenv('OPENAI_API_KEY')
for key in [telegram_api_id, telegram_api_hash, openai_key]:
    if key is None:
        raise ValueError(f"Missing environment variable: {key} in secrets.env file. Please set it up before running the script.")

# %%
# Download the dataset
database_link = "https://zenodo.org/records/14965395/files/eurepoc_global_dataset_1_3.csv?download=1"
cyber_database = pd.read_csv(database_link, sep=",", encoding="utf-8")
cyber_database
# Out:
#       incident_id                                               name  \
# 0            4163   Russian State-Sponsored Actors Linked to GRU ...
# 1            4161  Unknown threat actors stole Microsoft Azure ac...
# 2            4160  Unspecified US intelligence agencies stole tra...
# 3            4159  Unspecified US intelligence agency stole trade...
# 4            4158  Unknown Threat Actors breached the Attorney Ge...
# ...           ...                                                ...
# 3409            6                       "First Sino-US-Cyber-War" II
# 3410            5  Honker Union of China defaced US government an...
# 3411            4  Chinese hacktivists targeted Taiwanese governm...
# 3412            3  Armenian hacktivists target Azerbaijani webpag...
# 3413            2  Azerbaijani hackers took down and defaced Arme...
#
#                                             description  start_date  \
# 0     On 19 December 2024, a cyber attack attributed...  19.12.2024
# 1     Unit 42 researchers uncovered a phishing campa...  01.06.2024
# 2     The Chinese National Internet Emergency Respon...  01.05.2023
# 3     The Chinese National Internet Emergency Respon...  01.08.2024
# 4     In March 2024, a hacker breached the computer ...  01.03.2024
# ...                                                 ...         ...
# 3409  After the collision of an American spy plane a...  01.05.2001
# 3410  After the collision of an American spy plane a...  01.04.2001
# 3411  Chinese hackers succeeded in attacking several...  20.05.2000
# 3412  In response to previous DDoS-operations agains...  01.02.2000
# 3413  After an ethnic Armenian in California launche...  01.01.2000
#
#            end_date                                inclusion_criterion  \
# 0        19.12.2024  Attack conducted by nation state (generic “sta...
# 1     Not available        Attack on critical infrastructure target(s)
# 2     Not available  Attack conducted by nation state (generic “sta...
# 3     Not available  Attack conducted by nation state (generic “sta...
# 4     Not available  Attack on (inter alia) political target(s), no...
# ...             ...                                                ...
# 3409  Not available  Attack conducted by non-state group / non-stat...
# 3410  Not available  Attack conducted by non-state group / non-stat...
# 3411     20.05.2000  Attack conducted by non-state group / non-stat...
# 3412  Not available  Attack conducted by non-state group / non-stat...
# 3413  Not available  Attack conducted by non-state group / non-stat...
#
#       inclusion_criterion_subcode  \
# 0     Not available;Not available
# 1                   Not available
# 2                   Not available
# 3     Not available;Not available
# 4                   Not available
# ...                           ...
# 3409  Not available;Not available
# 3410  Not available;Not available
# 3411  Not available;Not available
# 3412  Not available;Not available
# 3413  Not available;Not available
#
#                                       source_disclosure  \
# 0     Incident disclosed by authorities of victim state
# 1             Incident disclosed by IT-security company
# 2     Incident disclosed by authorities of victim state
# 3     Incident disclosed by authorities of victim state
# 4                                         Not available
# ...                                                 ...
# 3409                     Incident disclosed by attacker
# 3410          Incident disclosed by IT-security company
# 3411                     Incident disclosed by attacker
# 3412                     Incident disclosed by attacker
# 3413                     Incident disclosed by attacker
#
#                                   incident_type  \
# 0              Disruption;Hijacking with Misuse
# 1              Data theft;Hijacking with Misuse
# 2              Data theft;Hijacking with Misuse
# 3              Data theft;Hijacking with Misuse
# 4     Data theft & Doxing;Hijacking with Misuse
# ...                                         ...
# 3409                                 Disruption
# 3410                                 Disruption
# 3411                                 Disruption
# 3412                                 Disruption
# 3413                                 Disruption
#
#                                           receiver_name  ...  \
# 0                         Ministry of Justice (Ukraine)  ...
# 1     Not available;Not available;Not available;Not ...  ...
# 2                                         Not available  ...
# 3                           Not available;Not available  ...
# 4               Attorney General's Office of Nuevo León  ...
# ...                                                 ...  ...
# 3409                                      Not available  ...
# 3410                        Not available;Not available  ...
# 3411                                      Not available  ...
# 3412          Not available;Not available;Not available  ...
# 3413          Not available;Not available;Not available  ...
#
#      legal_response_subtype legal_response_responding_country  \
# 0             Not available                           Ukraine
# 1             Not available                     Not available
# 2             Not available                     Not available
# 3             Not available                     Not available
# 4             Not available                     Not available
# ...                     ...                               ...
# 3409          Not available                     Not available
# 3410          Not available                     Not available
# 3411          Not available                     Not available
# 3412          Not available                     Not available
# 3413          Not available                     Not available
#
#         legal_response_responding_actor attribution_legal_reference  \
# 0     Security Service of Ukraine (SBU)               Not available
# 1                         Not available               Not available
# 2                         Not available               Not available
# 3                         Not available               Not available
# 4                         Not available               Not available
# ...                                 ...                         ...
# 3409                      Not available               Not available
# 3410                      Not available               Not available
# 3411                      Not available               Not available
# 3412                      Not available               Not available
# 3413                      Not available               Not available
#
#      attribution_legal_reference_subcode  \
# 0                          Not available
# 1                          Not available
# 2                          Not available
# 3                          Not available
# 4                          Not available
# ...                                  ...
# 3409                       Not available
# 3410                       Not available
# 3411                       Not available
# 3412                       Not available
# 3413                       Not available
#
#                                      response_indicator     casualties  \
# 0     Countermeasures under international law justif...  Not available
# 1     Unfriendly acts/retorsions justified (missing ...  Not available
# 2     Countermeasures under international law justif...  Not available
# 3     Countermeasures under international law justif...  Not available
# 4     Unfriendly acts/retorsions justified (missing ...  Not available
# ...                                                 ...            ...
# 3409                                      Not available  Not available
# 3410                                      Not available  Not available
# 3411                                      Not available  Not available
# 3412                                      Not available  Not available
# 3413                                      Not available  Not available
#
#                                              source_url added_to_db  \
# 0     https://www.t-online.de/nachrichten/ukraine/id...  2024-12-23
# 1     https://www.bleepingcomputer.com/news/security...  2024-12-20
# 2     https://cyberscoop.com/chinese-cyber-center-us...  2024-12-20
# 3     https://cyberscoop.com/chinese-cyber-center-us...  2024-12-20
# 4     https://mvsnoticias.com/nuevo-leon/2024/12/18/...  2024-12-20
# ...                                                 ...         ...
# 3409  https://www.nytimes.com/2001/05/13/weekinrevie...  2022-08-15
# 3410  https://www.nytimes.com/2001/05/13/weekinrevie...  2022-08-15
# 3411  http://www.hartford-hwp.com/archives/55/105.ht...  2022-08-15
# 3412                                      Not available  2022-08-15
# 3413  https://eurasianet.org/nagorno-karabakh-disput...  2022-08-15
#
#       updated_at
# 0     2025-02-18
# 1     2025-02-18
# 2     2025-02-18
# 3     2025-02-18
# 4     2025-02-04
# ...          ...
# 3409  2024-12-19
# 3410  2024-02-23
# 3411  2024-02-23
# 3412  2024-02-23
# 3413  2025-02-02
#
# [3414 rows x 85 columns]

# %% [markdown]
# ## Get links from data source

# %%
# Filter for incidents affecting Ukraine
links_regex = r"(https?://[^\s]+)"
ukraine_incidents = pd.DataFrame(cyber_database[cyber_database["initiator_country"].str.contains("Ukraine", na=False)])

# Extract links from the 'attribution_basis' column
ukraine_incidents["extracted_links"] = ukraine_incidents["attribution_source_url"].apply(
    lambda text: re.findall(links_regex, text) if isinstance(text, str) else []
)
links = ukraine_incidents["extracted_links"].explode().dropna().unique()
pd.DataFrame(links)
# Out:
#                                                     0
# 0   https://kyivindependent.com/hur-gazprombank-cy...
# 1   https://x.com/sudormRF6/status/184315307953504...
# 2   https://www.ukrinform.ua/rubric-ato/3898491-ki...
# 3   https://www.ukrinform.net/rubric-society/38961...
# 4                https://t.me/cyber_anarchy_squad/215
# ..                                                ...
# 68  https://www.bleepingcomputer.com/news/security...
# 69  https://medium.com/dfrlab/breaking-down-the-su...
# 70  https://web.archive.org/web/20171202045106/htt...
# 71  https://www.welivesecurity.com/wp-content/uplo...
# 72  https://www.securityweek.com/ukrainian-hackers...
#
# [73 rows x 1 columns]

# %% [markdown]
# ## Configure Workflow

# %%
from pydantic import BaseModel
from typing import List

# Setup scraper
# This will ask for a QR code to be scanned
telegram_scraper = TelegramMessageScraper(telegram_api_id, telegram_api_hash, session_name="my_session")
multi_scraper = UkraineCyberMultiScraper(telegram_message_scraper=telegram_scraper)

# Setup analyzer
instruction = """
Extract information from the text about the specific locations directly impacted by the cyber attack. The locations must be more specific than the country (i.e., city or province).
If the text does not contain a specific location, return an empty list.
Also provide short evidence from the text that supports the location.
Return a JSON object with the following fields:
{
    "location": ["location1", "location2", ...],
    "evidence": ["evidence1", "evidence2", ...]
}
"""
class ExpectedOutput(BaseModel):
    location: List[str]
    evidence: List[str]
analyzer = OpenAiAnalyzer(
    api_key=openai_key,
    instruction = instruction,
    pydantic_schema=ExpectedOutput)

# Setup workflow
workflow = Workflow(multi_scraper, analyzer)
# Out:
# WARNING:root:Session file my_session does not exist.
# Please scan the QR code from the Telegram app:
#
#
#     █▀▀▀▀▀█ ▀▀███ ▄█▀██▀▄██ ▀  ▀▀ █▀▀▀▀▀█
#     █ ███ █ ▄ ▀█  ▄▄▄▀██▀▀ █ ▄ ██ █ ███ █
#     █ ▀▀▀ █ █  ▄▄███▄ ██ ██▀ ▀▄▀█ █ ▀▀▀ █
#     ▀▀▀▀▀▀▀ █ █ ▀▄▀ ▀▄█ ▀ █▄▀ █▄▀ ▀▀▀▀▀▀▀
#     ▀▄▄▄█ ▀▀▀███ ▄▄▀▄▄▀█▄ ▀▀▀▀  █▀▀▀██ ▄▀
#     ▀▀ ▀▄ ▀█▄█ █ ▄▀ ▀▄▀ ▀▄█ ▄ ██▄▀▀   █▀▄
#      ▄▄▄██▀▀█▄▀▀█▀ █▀█▀▀ ▀▀█▄▀▄▄▄▀▀▀▄ ▄▀▀
#      ▄▄▀▀ ▀▀ ▀▀▄▀█ ▀█ ▀▄██▀█   ▀▄███▀█▄
#      ▀▀▄▄▀▀  ▀▀▄▀█▄ ▀ ▄▄▀▄▄▀▄█▄█▄▀█▄▄▄▀▀
#     ▄ ▀ ▄█▀▀▄  █▄▄██▄█ █▄▄ █▀ ▄█ ▄█▀█▀▄▄
#      ▄ █▀█▀█    ▀██▄█▀▄▄ ▄█▄ ▀ ▄▄▄▀▀▄█▄▀▀
#     ▀▄▀▀ ▀▀▀█▀█ ▀▄██▄█▄▄▄ ▄▀▀ ▄▀  ▀██▄▄█
#     ██▄ ▀▀▀▀██▀ ▄▀█ ▄▄▀▄▄▄▀ ▀█ ███▀▀█▄▀▄▀
#       █▄▄▄▀ ▀█ ▄▀▄█ ▀█▄ ▀▄█ ▄ ▄▀▀ █▀  ▄ ▄
#     ▀▀   ▀▀▀█▀ █▀█▀█▀█▀▀▀▀▀█▄█▄ █▀▀▀█▄▄█
#     █▀▀▀▀▀█ ▀█ ▀▄▀▄▀▄ ▀ ▄█▀▀▄▀  █ ▀ █ ▄▀
#     █ ███ █ ▀▀▄▀█▄▄ ▀ ▄▄▀▄▄ █   ▀███▀ ██▀
#     █ ▀▀▀ █  █ █▀█▀█▄█▀█▄▄▄▀█▀▄▄▀ ▀▀ ▀██
#     ▀▀▀▀▀▀▀ ▀▀   ▀▀  ▀  ▀ ▀ ▀▀ ▀ ▀▀   ▀▀▀
#
#
# [IngressRule(match=re.compile('https://cert.gov.ua/article/\\d+'), scraper=<scraipe_cyber.ukraine.cert_ua_scraper.CertUaScraper object at 0x7f3642afd2e0>), IngressRule(match=re.compile('https://t.me/[^/]+/[0-9]+'), scraper=<scraipe.extended.telegram_message_scraper.TelegramMessageScraper object at 0x7f3650de4f80>), IngressRule(match=re.compile('.*'), scraper=<scraipe.defaults.text_scraper.TextScraper object at 0x7f36518046b0>), IngressRule(match=re.compile('.*'), scraper=<scraipe.defaults.text_scraper.TextScraper object at 0x7f36518048f0>)]

# %% [markdown]
# ## Run Workflow

# %%
# Scrape links
workflow.scrape(links)
workflow.get_scrapes().head()
# Out:
# Scraping:   0%|          | 0/73 [00:00<?, ?link/s]
# ERROR:root:Failed to scrape https://t.me/cyberResistanceUA/397: Message 397 from cyberResistanceUA is None.
# ERROR:root:Failed to scrape https://t.me/sudo_RM_RF_6/37: Failed to get chat for {chat_name}
# ERROR:root:Failed to scrape https://t.me/dfhmara/41: Failed to get chat for {chat_name}
#                                                 link  \
# 0              https://t.me/itarmyofukraine2022/1701
# 1  https://gur.gov.ua/en/content/voienna-rozvidka...
# 2  https://www.ukrinform.ua/rubric-ato/3898491-ki...
# 3                https://www.kyivpost.com/post/31798
# 4  https://twitter.com/cyber_etc/status/151786767...
#
#                                              content  scrape_success  \
# 0  Поки ви тут пили лате, наші великородні північ...            True
# 1  Defence Intelligence of Ukraine conducted a cy...            True
# 2  Кіберфахівці ГУР заблокували десятки ресурсів ...            True
# 3  Ukrainian Hackers Launch Cyberattacks on Subsi...            True
# 4                                               None           False
#
#                                         scrape_error metadata
# 0                                               None     None
# 1                                               None     None
# 2                                               None     None
# 3                                               None     None
# 4  No scraper could handle link; TextScraper[FAIL...     None

# %%
# Extract location info with LLM
workflow.analyze()
workflow.get_analyses()
# Out:
# Analyzing:   0%|          | 0/52 [00:00<?, ?link/s]
#                                                  link  \
# 0               https://t.me/itarmyofukraine2022/1701
# 1   https://gur.gov.ua/en/content/voienna-rozvidka...
# 2   https://www.ukrinform.ua/rubric-ato/3898491-ki...
# 3                 https://www.kyivpost.com/post/31798
# 4   https://jeffreycaruso.substack.com/p/another-g...
# 5   https://jeffreycarr.substack.com/p/kalashnikov...
# 6                           https://t.me/Hdr0_one/130
# 7                https://t.me/itarmyofukraine2022/763
# 8   https://www.ukrinform.net/rubric-society/38961...
# 9   https://www.newsweek.com/us-consulate-hacked-p...
# 10  https://jeffreycarr.substack.com/p/ukraines-de...
# 11                 https://t.me/s/itarmyofukraine2022
# 12               https://t.me/cyber_anarchy_squad/215
# 13  https://therecord.media/russian-railway-site-t...
# 14  https://jeffreycarr.substack.com/p/rostelecoms...
# 15                          https://t.me/Hdr0_one/132
# 16  https://www.ibtimes.com/team-onefist-hackers-s...
# 17  https://en.interfax.com.ua/news/telecom/979145...
# 18         http://www.cyber-berkut.ru/en/index_02.php
# 19  https://edition.cnn.com/2024/03/31/politics/na...
# 20  https://jeffreycarr.substack.com/p/the-mysteri...
# 21  https://securityaffairs.com/153192/hacktivism/...
# 22  https://www.thedailybeast.com/hackers-force-vl...
# 23  https://www.ibtimes.com/russians-novosibirsk-f...
# 24              https://www.kommersant.ru/doc/5841058
# 25  https://securityaffairs.co/wordpress/128563/da...
# 26  https://kyivindependent.com/hur-gazprombank-cy...
# 27  https://gur.gov.ua/content/ukrainska-rozvidka-...
# 28  https://therecord.media/ukraine-hackers-deface...
# 29  https://gur.gov.ua/en/content/soft-shyfry-sekr...
# 30  https://jeffreycarr.substack.com/p/gurmo-hacke...
# 31              https://t.me/itarmyofukraine2022/1054
# 32     https://securelist.com/cloudwizard-apt/109722/
# 33  https://www.hackread.com/anonymous-hits-russia...
# 34  https://medium.com/dfrlab/breaking-down-the-su...
# 35  https://gur.gov.ua/content/u-rashystiv-masshta...
# 36                https://www.kyivpost.com/post/34195
# 37  https://jeffreycarr.substack.com/p/jsc-bifit-b...
# 38            https://tass.ru/proisshestviya/17778413
# 39               https://t.me/itarmyofukraine2022/855
# 40  https://iz-ru.translate.goog/1305747/2022-03-1...
# 41  https://kyivindependent.com/source-hur-confirm...
# 42                        https://t.me/DIUkraine/3341
# 43  https://jeffreycaruso.substack.com/p/russias-f...
# 44  https://jeffreycarr.substack.com/p/russias-fac...
# 45  https://www.scmagazine.com/analysis/breach/in-...
# 46                        https://t.me/zedigital/2445
# 47               https://t.me/itarmyofukraine2022/851
# 48  http://web.archive.org/web/20231004195529/http...
# 49  https://gur.gov.ua/en/content/zlam-federalnoi-...
# 50  https://jeffreycarr.substack.com/p/vsb-bank-br...
# 51  https://www.bleepingcomputer.com/news/security...
#
#                                                output  analysis_success  \
# 0                    {'location': [], 'evidence': []}              True
# 1                    {'location': [], 'evidence': []}              True
# 2   {'location': ['Острогозьк', 'Чайка-сервіс'], '...              True
# 3   {'location': ['Moscow', 'St. Petersburg'], 'ev...              True
# 4   {'location': ['Yambur'], 'evidence': ['a secti...              True
# 5                    {'location': [], 'evidence': []}              True
# 6   {'location': ['Крым', 'Алтайский Край'], 'evid...              True
# 7                    {'location': [], 'evidence': []}              True
# 8   {'location': ['Snezhinsk', 'Chelyabinsk region...              True
# 9   {'location': ['Milan'], 'evidence': ['The U.S....              True
# 10  {'location': ['Vostochny Cosmodrome', 'Amur Ob...              True
# 11                   {'location': [], 'evidence': []}              True
# 12  {'location': ['Краснодар', 'Москва'], 'evidenc...              True
# 13                   {'location': [], 'evidence': []}              True
# 14  {'location': ['Sochi', 'Leningrad', 'Kyiv'], '...              True
# 15  {'location': ['Санкт-Петербург', 'Москва'], 'e...              True
# 16  {'location': ['Rostov', 'Kherson'], 'evidence'...              True
# 17  {'location': ['Moscow', 'Moscow region'], 'evi...              True
# 18                   {'location': [], 'evidence': []}              True
# 19  {'location': ['Arctic penal colony'], 'evidenc...              True
# 20  {'location': ['Houston, TX', 'Moscow', 'Nizhne...              True
# 21  {'location': ['territories occupied by Russia'...              True
# 22  {'location': ['Peredelkino', 'Moscow', 'Kyiv']...              True
# 23  {'location': ['Novosibirsk'], 'evidence': ['th...              True
# 24  {'location': ['Белгородская область', 'Воронеж...              True
# 25  {'location': ['South Africa', 'Peru', 'Canada'...              True
# 26  {'location': ['France', 'Germany'], 'evidence'...              True
# 27  {'location': ['Перм'], 'evidence': ['пєрмскій ...              True
# 28                   {'location': [], 'evidence': []}              True
# 29                   {'location': [], 'evidence': []}              True
# 30                   {'location': [], 'evidence': []}              True
# 31                   {'location': [], 'evidence': []}              True
# 32  {'location': ['Donetsk', 'Lugansk', 'Crimea', ...              True
# 33  {'location': ['Blagoveshchensk', 'Tver'], 'evi...              True
# 34  {'location': ['Donetsk', 'Luhansk', 'Abkhazia'...              True
# 35                   {'location': [], 'evidence': []}              True
# 36  {'location': ['Domodedovo Airport', 'Saratov',...              True
# 37                   {'location': [], 'evidence': []}              True
# 38  {'location': ['Ростов-на-Дону'], 'evidence': [...              True
# 39                   {'location': [], 'evidence': []}              True
# 40  {'location': ['Дальний Восток', 'Сибирь', 'Ура...              True
# 41  {'location': ['Kyiv'], 'evidence': ['Zelensky ...              True
# 42  {'location': ['Москва'], 'evidence': ['у москв...              True
# 43                   {'location': [], 'evidence': []}              True
# 44  {'location': ['Dubna'], 'evidence': ['The Join...              True
# 45  {'location': ['Beloyarsk'], 'evidence': ['The ...              True
# 46  {'location': ['Ukraine'], 'evidence': ['which ...              True
# 47                   {'location': [], 'evidence': []}              True
# 48  {'location': ['Крым'], 'evidence': ['The russi...              True
# 49  {'location': ['Crimea', 'Moscow'], 'evidence':...              True
# 50  {'location': ['Lubyanka street'], 'evidence': ...              True
# 51  {'location': ['Ukraine'], 'evidence': ['Rostec...              True
#
#    analysis_error
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26           None
# 27           None
# 28           None
# 29           None
# 30           None
# 31           None
# 32           None
# 33           None
# 34           None
# 35           None
# 36           None
# 37           None
# 38           None
# 39           None
# 40           None
# 41           None
# 42           None
# 43           None
# 44           None
# 45           None
# 46           None
# 47           None
# 48           None
# 49           None
# 50           None
# 51           None

# %% [markdown]
# ## Output

# %%
# Export results
export = workflow.export(verbose=True)
# Display rows with locations extracted
display(export[export["location"].str.len() > 0].head())
# Out:
#                                                  link  scrape_success  \
# 2   https://www.ukrinform.ua/rubric-ato/3898491-ki...            True
# 3                 https://www.kyivpost.com/post/31798            True
# 5   https://jeffreycaruso.substack.com/p/another-g...            True
# 7                           https://t.me/Hdr0_one/130            True
# 13  https://www.ukrinform.net/rubric-society/38961...            True
#
#    scrape_error  analysis_success analysis_error  \
# 2          None              True           None
# 3          None              True           None
# 5          None              True           None
# 7          None              True           None
# 13         None              True           None
#
#                            location  \
# 2        [Острогозьк, Чайка-сервіс]
# 3          [Moscow, St. Petersburg]
# 5                          [Yambur]
# 7            [Крым, Алтайский Край]
# 13  [Snezhinsk, Chelyabinsk region]
#
#                                              evidence
# 2   [уражено польовий склад боєприпасів, розташова...
# 3   [caused severe disruption to internet services...
# 5   [a section of the Yambur gas pipeline — Elets-...
# 7   [временного оккупации Крыма, временного оккупа...
# 13  [the Internet service provider Vega from the c...

# %%
# Number of links that were successfuly scraped and analyzed
success_count = (export["scrape_success"] & export["analysis_success"]).sum()
print (f"Successfully scraped and analyzed links: {success_count}/{len(export)} ({success_count/len(export)*100:.2f}%)")

# Number of successful extractions from analyses
populated_count = (export["location"].str.len() > 0).sum()
print (f"Successfully extracted locations from analyses: {populated_count}/{success_count} ({populated_count/success_count*100:.2f}%)")
# Out:
# Successfully scraped and analyzed links: 52/73 (71.23%)
# Successfully extracted locations from analyses: 36/52 (69.23%)
